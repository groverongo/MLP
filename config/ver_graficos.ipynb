# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("../data/perdidas.csv", header=None)
plt.plot(df.index, df.values)

# %%
import numpy as np
df = pd.read_csv("../data/nuevo/nuevo.csv", header=None)
df_arr = df.to_numpy()
df_argmax = np.argmax(df_arr, axis=1)

t = pd.read_csv("../res/training.csv",header=None)
print(t.shape)
t_arr = t.iloc[:, 128:].to_numpy()
t_argmax = np.argmax(t_arr, axis=1)
np.sum(np.equal(t_argmax, df_argmax))
# Out:
# (1700, 152)
# 1696
